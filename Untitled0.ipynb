# %% [markdown]
# <a href="https://colab.research.google.com/github/IndahPurnama12/Tugas-NLP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ Install libraries (jalankan di Google Colab)
# !pip install transformers datasets evaluate sentencepiece PyMuPDF fpdf --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 23.7 MB/s eta 0:00:00
# ...

# %%
# ✅ 1. Mount Google Drive
from google.colab import drive
import fitz  # PyMuPDF
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ganti dengan path file PDF kamu
pdf_kalimat_path = "/content/drive/MyDrive/Tugas NLP/Dataset_Indo_Sunda_Translation_Lengkap.pdf"
pdf_kata_path = "/content/drive/MyDrive/Tugas NLP/Dataset_Indo_Sunda_Perkata_500.pdf"

# %%
# ✅ 2. Ekstrak isi PDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

text_kalimat = extract_text_from_pdf(pdf_kalimat_path)
text_kata = extract_text_from_pdf(pdf_kata_path)

# %%
# ✅ 3. Parsing baris ke dalam list

def parse_pdf_text(text):
    lines = [line.strip() for line in text.strip().split('\n') if line.strip()]
    indo = lines[3::2]
    sunda = lines[4::2]
    return indo[:len(sunda)], sunda

indo_kal, sunda_kal = parse_pdf_text(text_kalimat)
indo_kat, sunda_kat = parse_pdf_text(text_kata)

# Gabungkan dua dataset
indo_all = indo_kal + indo_kat
sunda_all = sunda_kal + sunda_kat

# %%
# ✅ 4. Buat Dataset HuggingFace
from datasets import Dataset

data = Dataset.from_dict({"id_text": indo_all, "su_text": sunda_all})

# %%
# ✅ 5. Tokenizer dan Model T5
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# ...

# %%
# ✅ 6. Preprocessing Function

def preprocess_function(examples):
    inputs = [f"translate Indonesian to Sundanese: {text}" for text in examples["id_text"]]
    targets = examples["su_text"]
    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")

    labels = tokenizer(targets, max_length=128, truncation=True, padding="max_length")
    labels["input_ids"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
    ]
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = data.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/530 [00:00<?, ? examples/s]

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# ✅ 7. Training
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer
from evaluate import load
import torch

training_args = Seq2SeqTrainingArguments(
    output_dir="./indo-sunda-t5",
    per_device_train_batch_size=4,
    num_train_epochs=5,
    learning_rate=5e-4,
    logging_dir="./logs",
    predict_with_generate=True,
    fp16=torch.cuda.is_available(),
    report_to="none"
)

bleu = load("sacrebleu")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = [[(l if l != -100 else tokenizer.pad_token_id) for l in label] for label in labels]
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    decoded_labels = [[label] for label in decoded_labels]
    return bleu.compute(predictions=decoded_preds, references=decoded_labels)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# <ipython-input-13-ad5aeb01304f>:27: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='665' max='665' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [665/665 01:37, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.838200</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
# ✅ 8. Fungsi translate interaktif

def translate(text):
    input_text = f"translate Indonesian to Sundanese: {text}"
    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, padding=True, max_length=128).to(model.device)
    outputs = model.generate(**inputs, max_length=50, num_beams=5, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
# ✅ 9. Uji terjemahan
while True:
    src = input("\nMasukkan kalimat Bahasa Indonesia (atau 'exit'): ")
    if src.lower() == 'exit':
        break
    print("Terjemahan Bahasa Sunda:", translate(src))
# Out:
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): makan
# Terjemahan Bahasa Sunda: tuang
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): pulang sekolah
# Terjemahan Bahasa Sunda: mulang sakola
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): pergi pasar
# Terjemahan Bahasa Sunda: angkat
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): makan pisang
# Terjemahan Bahasa Sunda: pisang
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): habis
# Terjemahan Bahasa Sunda: habis
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): bisa
# Terjemahan Bahasa Sunda: bisa
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): kepala
# Terjemahan Bahasa Sunda: leutik
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): makan nangka
# Terjemahan Bahasa Sunda: tuang
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): celana
# Terjemahan Bahasa Sunda: nabel
#
# Masukkan kalimat Bahasa Indonesia (atau 'exit'): exit

# %%
print(tokenized_dataset[0]["labels"])
# Out:
# [7118, 370, 1, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100]

# %%
sample = tokenized_dataset[0]
input_ids = torch.tensor(sample["input_ids"]).unsqueeze(0).to(model.device)
labels = torch.tensor(sample["labels"]).unsqueeze(0).to(model.device)

model.eval()
with torch.no_grad():
    output = model(input_ids=input_ids, labels=labels)
    print("Manual loss:", output.loss.item())
# Out:
# Manual loss: nan

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    eval_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# <ipython-input-14-013c20e9cf3c>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='43' max='665' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 43/665 00:06 < 01:40, 6.20 it/s, Epoch 0.32/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
# ...

# %%
def translate(text):
    prompt = f"translate Indonesian to Sundanese: {text}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True, max_length=128).to(model.device)
    outputs = model.generate(**inputs, max_length=50, num_beams=5, early_stopping=True)
    result = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return result

# Interaktif
while True:
    text = input("Masukkan kalimat Bahasa Indonesia (atau ketik 'exit'): ")
    if text.lower() == 'exit':
        break
    hasil = translate(text)
    print("Terjemahan Bahasa Sunda:", hasil, "\n")
# Out:
# Masukkan kalimat Bahasa Indonesia (atau ketik 'exit'): saya mau ke pasar
# Terjemahan Bahasa Sunda: <extra_id_0>-i俑истенциXzFfㄔ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-eea4d7545ffb> in <cell line: 0>()
#       8 # Interaktif
#       9 while True:
# ---> 10     text = input("Masukkan kalimat Bahasa Indonesia (atau ketik 'exit'): ")
#      11     if text.lower() == 'exit':
#      12         break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
